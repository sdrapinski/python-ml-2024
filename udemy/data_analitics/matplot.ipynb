# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

plt.plot(x,y)

# %%
x = [1,2,3,4,5,6]
y1 = [1,4,9,12,15,21]
y2 = [1,2,3,4,5]

plt.figure(figsize=(9,6))

plt.subplot(1,2,1)
plt.plot(x,y1,color="green")
